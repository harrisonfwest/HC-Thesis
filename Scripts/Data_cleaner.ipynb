# %%
import numpy as np
import pandas as pd
from astropy.io import fits
from astropy.table import Table
import scipy
import matplotlib.pyplot as plt

# %%
hdul = fits.open("../Data/HI-MaNGA-WithZhou-MA-AllColumns.fits")
dataTable = Table(hdul[1].data)
dataTable
# Out:
# <Table length=358>
#  PLATEIFU_1 MANGAID        OBJRA        ... ang_stellar_err  ang_ha ang_ha_err
#    str11      str9        float64       ...     float32     float32  float32
# ----------- -------- ------------------ ... --------------- ------- ----------
#  10001-3702  1-48136      132.912768243 ...           12.25   148.0       17.5
#  10213-1901  1-72595      124.082783686 ...            17.0   297.5       9.25
#  10215-1902 1-153901      123.857378368 ...           11.75   336.5       5.75
#  10220-1901 1-153127      120.805213561 ...            26.0    32.0       6.75
#  10220-3703 1-201936      120.576629639 ...            4.25   281.0        0.5
#  10222-3703  1-50622      43.5219976469 ...            36.5    31.5        1.0
#  10224-3701  1-35937      34.3991810957 ...            8.25   324.0       0.75
# 10500-12703 1-300461      137.160232544 ...            4.75   318.5       3.25
#  10510-1901 1-189283      178.779249963 ...            15.0   311.0        3.5
# ...
